# %%
import pandas as pd

# %%
test_csv = pd.read_csv('test.csv')
train_csv = pd.read_csv('train.csv')

# %%
test_df = pd.DataFrame(test_csv)
train_df = pd.DataFrame(train_csv)

# %%
test_df.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour    ...     3Ssn Porch Screen Porch Pool Area  \
# 0  Grvl       Reg          Lvl    ...              0            0         0
# 1   NaN       IR1          Lvl    ...              0            0         0
# 2   NaN       IR1          Lvl    ...              0            0         0
# 3   NaN       Reg          Lvl    ...              0            0         0
# 4   NaN       IR1          Lvl    ...              0          185         0
#
#   Pool QC Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# ...

# %%
train_df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour    ...     Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl    ...                0         0     NaN   NaN
# 1       IR1          Lvl    ...                0         0     NaN   NaN
# 2       Reg          Lvl    ...                0         0     NaN   NaN
# 3       Reg          Lvl    ...                0         0     NaN   NaN
# 4       IR1          Lvl    ...                0         0     NaN   NaN
#
# ...

# %%
#1. EDA: see what our training set looks like
#train_df.info()
train_df.describe()
train_df.shape
len(train_df.select_dtypes(exclude = 'object').columns)
len(train_df.select_dtypes(include = 'object').columns)
# Out:
# 42

# %%
#how many columns are numeric?
#train_df[train_df.types == 'int64']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour    ...     Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl    ...                0         0     NaN   NaN
# 1       IR1          Lvl    ...                0         0     NaN   NaN
# 2       Reg          Lvl    ...                0         0     NaN   NaN
# 3       Reg          Lvl    ...                0         0     NaN   NaN
# 4       IR1          Lvl    ...                0         0     NaN   NaN
#
# ...

# %%
#looking at subset of data to see which are most highly correlated with target: price
#QUESTION: how to return the top 25 and bottom 25 percentile correlation values?
    #pass 1: arbitrarily choosing r = 0.75 as threshold here to generate a first pass feature set of 10-15 features
        #returns 1 feature: 'Overall Qual'
    #pass 2: arbitrarily choosing r = 0.5 as threshold
        #returns 11 features: 'Overall Qual', 'Garage Area', 'Garage Cars', 'Total Bsmt SF', '1st Fl SF', 'Year Built',
        #'Year Remod/Add', 'Full Bath', 'Garage Yr Blt', 'Mas Vnr Area', 'TotRms AbvGrd'

corr = train_df.corr()[['SalePrice']].sort_values(by = 'SalePrice', ascending = False)
#corr.rank(ascending = False)

import matplotlib.pyplot as plt
import seaborn as sns
#QUESTION: why does this not return the correlations of all 81 variables?
figure = plt.figure(figsize = (12, 8))
sns.heatmap(corr.rank(ascending = False), annot = corr);

# %%
import numpy as np

#above only looking at numeric features
#train_df.iloc[:,:-1]
#train_df.iloc[:, -1]

#see correlation for string features
#np.corrcoef(train_df[train_df])
#np.corrcoef(train_df)

# %%
subset = train_df.loc[:,['Overall Qual', 
                'Garage Area', 
                'Garage Cars', 
                'Total Bsmt SF', 
                '1st Fl SF', 
                'Year Built',
                'Year Remod/Add', 
                'Full Bath', 
                'Garage Yr Blt', 
                'Mas Vnr Area', 
                'TotRms AbvGrd',
                'SalePrice']]

subset.head()
# Out:
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel/__main__.py:12: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/core/indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#    Overall Qual  Garage Area  Garage Cars  Total Bsmt SF  1st Fl SF  \
# 0             6        475.0          2.0          725.0        NaN
# 1             7        559.0          2.0          913.0        NaN
# ...

# %%
#looking at subset of data with above 0.5 correlation with SalePrice
    #don't brute force and run everything --> energy expenditure

fig = plt.figure(figsize = (20, 10))
    
for i, col in enumerate(subset.columns):
    fig.add_subplot(3, 4, i+1)
    plt.scatter(subset[col], subset['SalePrice']);
    plt.xlabel(col)
    plt.ylabel('SalePrice')

# %%
#one variable: '1st Fl SF' does not show up
    #let's check the data type --> float64 type but all nulls --> remove from feature set
subset.dtypes
    #check for nulls --> we did this at the beginning with .info() and should have done it while creating the subset
subset.isnull().sum()
subset = subset.drop('1st Fl SF', axis = 1)
subset.head()
# Out:
#    Overall Qual  Garage Area  Garage Cars  Total Bsmt SF  Year Built  \
# 0             6        475.0          2.0          725.0        1976
# 1             7        559.0          2.0          913.0        1996
# 2             5        246.0          1.0         1057.0        1953
# 3             5        400.0          2.0          384.0        2006
# 4             6        484.0          2.0          676.0        1900
#
#    Year Remod/Add  Full Bath  Garage Yr Blt  Mas Vnr Area  TotRms AbvGrd  \
# 0            2005          2         1976.0         289.0              6
# 1            1997          2         1997.0         132.0              8
# 2            2007          1         1953.0           0.0              5
# 3            2007          2         2007.0           0.0              7
# 4            1993          2         1957.0           0.0              6
#
#    SalePrice
# 0     130500
# 1     220000
# 2     109000
# 3     174000
# 4     138500

# %%
subset.dropna(inplace = True)
subset.isnull().sum()
# Out:
# Overall Qual      0
# Garage Area       0
# Garage Cars       0
# Total Bsmt SF     0
# Year Built        0
# Year Remod/Add    0
# Full Bath         0
# Garage Yr Blt     0
# Mas Vnr Area      0
# TotRms AbvGrd     0
# SalePrice         0
# dtype: int64

# %%
#we can also rename the columns to be more analysis friendly
    #lowercase, remove spaces
subset.columns = [i.lower().replace(' ','') for i in subset.columns]
subset.head()
# Out:
#    overallqual  garagearea  garagecars  totalbsmtsf  yearbuilt  yearremod/add  \
# 0            6       475.0         2.0        725.0       1976           2005
# 1            7       559.0         2.0        913.0       1996           1997
# 2            5       246.0         1.0       1057.0       1953           2007
# 3            5       400.0         2.0        384.0       2006           2007
# 4            6       484.0         2.0        676.0       1900           1993
#
#    fullbath  garageyrblt  masvnrarea  totrmsabvgrd  saleprice
# 0         2       1976.0       289.0             6     130500
# 1         2       1997.0       132.0             8     220000
# 2         1       1953.0         0.0             5     109000
# 3         2       2007.0         0.0             7     174000
# 4         2       1957.0         0.0             6     138500

# %%
#are there categorical variables that we could split via pd.dummies?
    #'Overall Qual', 'Garage Cars', 'Full Bath', 'TotRms AbvGrd'

import pandas as pd
#subset = pd.get_dummies(data = subset, columns = ['overallqual', 'garagecars', 'fullbath', 'totrmsabvgrd'], drop_first = True)
subset.head()
# Out:
#    overallqual  garagearea  garagecars  totalbsmtsf  yearbuilt  yearremod/add  \
# 0            6       475.0         2.0        725.0       1976           2005
# 1            7       559.0         2.0        913.0       1996           1997
# 2            5       246.0         1.0       1057.0       1953           2007
# 3            5       400.0         2.0        384.0       2006           2007
# 4            6       484.0         2.0        676.0       1900           1993
#
#    fullbath  garageyrblt  masvnrarea  totrmsabvgrd  saleprice
# 0         2       1976.0       289.0             6     130500
# 1         2       1997.0       132.0             8     220000
# 2         1       1953.0         0.0             5     109000
# 3         2       2007.0         0.0             7     174000
# 4         2       1957.0         0.0             6     138500

# %%
#let's look at subset again after some cleanup

fig = plt.figure(figsize = (20, 8))
sns.heatmap(subset.corr(), annot = True);

# %%
#sns.pairplot(subset)
subset.shape
# Out:
# (1915, 11)

# %%
#Instantiate our first model / lin reg

from sklearn.linear_model import LinearRegression
features = [col for col in subset.columns if (col != 'saleprice' and col != 'filler')]
X = subset[features]
y = subset['saleprice']

lr = LinearRegression()
lr.fit(X, y)
lr.score(X, y)

display(features)
# Out:
# ['overallqual',
#  'garagearea',
#  'garagecars',
#  'totalbsmtsf',
#  'yearbuilt',
#  'yearremod/add',
#  'fullbath',
#  'garageyrblt',
#  'masvnrarea',
#  'totrmsabvgrd']

# %%
import statsmodels.api as sm

#QUESTION: wouldn't we expect the R-squared output to be 0.82 (same as above)?
#adding filler for Beta-naught intercept and multiplying by 1
subset['filler'] = 1

model=sm.OLS(y, X)
result=model.fit()
result.summary()
# Out:
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              saleprice   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     5073.
# Date:                Fri, 18 May 2018   Prob (F-statistic):               0.00
# Time:                        07:51:12   Log-Likelihood:                -22927.
# No. Observations:                1915   AIC:                         4.587e+04
# Df Residuals:                    1905   BIC:                         4.593e+04
# Df Model:                          10
# ...

# %%
test_df.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
test_df.columns = [i.lower().replace(' ', '') for i in test_df.columns]
subset_test = test_df.loc[:, ['id', 'garagearea', 'totalbsmtsf', 'yearbuilt', 'yearremod/add', 'garageyrblt', 'masvnrarea',
                             'overallqual', 'garagecars', 'fullbath', 'totrmsabvgrd']]
subset_test.isnull().sum()
# Out:
# id                0
# garagearea        0
# totalbsmtsf       0
# yearbuilt         0
# yearremod/add     0
# garageyrblt      45
# masvnrarea        1
# overallqual       0
# garagecars        0
# fullbath          0
# totrmsabvgrd      0
# dtype: int64

# %%
subset_test.head()
#subset_test.drop(['garageyrblt'], axis = 1, inplace = True)
# Out:
#      id  garagearea  totalbsmtsf  yearbuilt  yearremod/add  garageyrblt  \
# 0  2658       440.0       1020.0       1910           1950       1910.0
# 1  2718       580.0       1967.0       1977           1977       1977.0
# 2  2414       426.0        654.0       2006           2006       2006.0
# 3  1989       480.0        968.0       1923           2006       1935.0
# 4   625       514.0       1394.0       1963           1963       1963.0
#
#    masvnrarea  overallqual  garagecars  fullbath  totrmsabvgrd
# 0         0.0            6         1.0         2             9
# 1         0.0            5         2.0         2            10
# 2         0.0            7         2.0         2             7
# 3         0.0            5         2.0         1             5
# 4       247.0            6         2.0         1             6

# %%
#subset_test = pd.get_dummies(subset_test, columns = ['overallqual', 'garagecars', 'fullbath', 'totrmsabvgrd'], drop_first = True)
#subset_test.dropna(axis = 0, how = 'any', inplace = True)

#replacing NaN value with 0.0
subset_test.loc[866, 'masvnrarea'] = 0
subset_test.isnull().sum()

#subset_test.columns
# Out:
# id                0
# garagearea        0
# totalbsmtsf       0
# yearbuilt         0
# yearremod/add     0
# garageyrblt      45
# masvnrarea        0
# overallqual       0
# garagecars        0
# fullbath          0
# totrmsabvgrd      0
# dtype: int64

# %%
#reinstantiate model b/c we've removed 'gargeyrblt'
features = [col for col in subset.columns if (col != 'saleprice' and col != 'garageyrblt' and col != 'filler')]
X = subset[features]
y = subset['saleprice']

lr = LinearRegression()
lr.fit(X, y)
print(lr.score(X, y))

predictions = lr.predict(X)
predictions.mean()
# Out:
# 0.7689600501084325
# 185364.26318537875

# %%
subset_test.shape
subset_test.columns
# Out:
# Index(['id', 'garagearea', 'totalbsmtsf', 'yearbuilt', 'yearremod/add',
#        'garageyrblt', 'masvnrarea', 'overallqual', 'garagecars', 'fullbath',
#        'totrmsabvgrd'],
#       dtype='object')

# %%
subset_test['saleprice'] = subset_test.saleprice.round(2)
subset_test.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-539afae1c94c> in <module>()
# ----> 1 subset_test['saleprice'] = subset_test.saleprice.round(2)
#       2 subset_test.head()
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'saleprice'

# %%
#my_sample = pd.concat([test_df.id, subset_test.saleprice])

# %%
sample = pd.DataFrame(pd.read_csv('sample_sub_reg.csv'))

# %%
sample['Id'] = test_df.id
sample['SalePrice'] = predictions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-c68cf033ca68> in <module>()
#       1 sample['Id'] = test_df.id
# ----> 2 sample['SalePrice'] = predictions
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2758
# ...

# %%
sample.head()
# Out:
#      Id    SalePrice
# 0  2658  19710917.38
# 1  2718  23335615.86
# 2  2414  19883515.49
# 3  1989  20658902.99
# 4   625  21704773.04

# %%
sample.to_csv('sample1_hc.csv')
#sample1.drop(['Unnamed: 0'], axis = 1, inplace = True)
#sample.set_index('id', inplace = True)

# %%
sample
# Out:
#        Id    SalePrice
# 0    2658  19710917.38
# 1    2718  23335615.86
# 2    2414  19883515.49
# 3    1989  20658902.99
# 4     625  21704773.04
# 5     333  16471596.01
# 6    1327  16915046.61
# 7     858  15760594.45
# 8      95  23544284.43
# 9    1568  20815333.89
# 10   2482  21135372.31
# 11   1364  17019568.17
# 12   2584  20185662.99
# 13    818  28890173.43
# 14   2673  15212703.79
# 15   2089  15612992.04
# 16   1297  28721676.43
# 17    790  17644191.68
# 18   2616  19486629.96
# 19    720  19181391.01
# 20    222  16121396.34
# 21    557  26615153.57
# 22   1148  22285358.34
# 23   2766  22269330.54
# 24    534  23334221.31
# 25   1452  17995588.76
# 26    630  18088042.19
# 27   2648  14950977.14
# 28    125  20897337.62
# 29   1904   9770818.11
# ..    ...          ...
# 849   933  20307869.43
# 850  2784  25367123.24
# 851   972  19554989.50
# 852   599  20413280.98
# 853  2614  16470273.17
# 854  2582  23694507.21
# 855  1409  18749966.58
# 856   175  18325494.95
# ...
