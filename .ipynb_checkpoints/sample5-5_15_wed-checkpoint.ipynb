# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = pd.DataFrame(pd.read_csv('train.csv'))
train.columns = [i.lower().replace(' ', '') for i in train.columns]

# %%
#from Tableau measures
train.loc[:, ['1stflrsf', '2ndflrsf', 'bsmtunfsf', 'bsmtfinsf1', 'garagearea', 'garageyrblt',
             'grlivearea', 'lotfrontage', 'masvnrarea', 'openporchsf', 'overallqual', 'screenporch', 'totalbsmtsf', 'totrmsabvgrd', 'wooddecksf', 'yearbuilt']].dtypes
# Out:
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   app.launch_new_instance()
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/core/indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# 1stflrsf          int64
# 2ndflrsf          int64
# bsmtunfsf       float64
# bsmtfinsf1      float64
# garagearea      float64
# garageyrblt     float64
# grlivearea      float64
# ...

# %%
X_train_num = train.loc[:, [#'id',
                            '1stflrsf', '2ndflrsf', 'bsmtunfsf', 'bsmtfinsf1', 'garagearea',
                            'garageyrblt', 'grlivearea', 'lotfrontage', 'masvnrarea', 
                            'openporchsf', 'overallqual', 'screenporch', 'totalbsmtsf', 
                            'totrmsabvgrd', 'wooddecksf', 'yearbuilt'
                            #'saleprice'
]]

y_train_num = train['saleprice']
# Out:
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel/__main__.py:5: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/core/indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
X_train_num.fillna(value = 0, inplace = True)
X_train_num.isnull().sum()
# Out:
# 1stflrsf        0
# 2ndflrsf        0
# bsmtunfsf       0
# bsmtfinsf1      0
# garagearea      0
# garageyrblt     0
# grlivearea      0
# lotfrontage     0
# masvnrarea      0
# openporchsf     0
# overallqual     0
# screenporch     0
# totalbsmtsf     0
# totrmsabvgrd    0
# wooddecksf      0
# yearbuilt       0
# dtype: int64

# %%
X_train_num_train, X_train_num_test, y_train_num_train, y_train_num_test = train_test_split(X_train_num, y_train_num, test_size = 0.25)
print(X_train_num_train.shape, y_train_num_train.shape)
print(X_train_num_test.shape, y_train_num_test.shape)
# Out:
# (1538, 16) (1538,)
# (513, 16) (513,)

# %%
#instantiate, fit and score a numerical linear model
lr = LinearRegression()
lr.fit(X_train_num_train, y_train_num_train)
lr.score(X_train_num_train, y_train_num_train)
# Out:
# 0.8041832588183422

# %%
#model is performing well on test set
    #higher score on test than train so underfit model --> higher bias
lr.score(X_train_num_test, y_train_num_test)
# Out:
# 0.8143425843132379

# %%
X_train_obj = train.loc[:, [
    'bsmtcond', 'centralair', 'condition1', 'condition2', 'electrical', 'exterqual',
    'fireplacequ', 'foundation', 'garagefinish', 'garagequal', 'garagetype', 'kitchenqual',
    'landcontour', 'landslope', 'lotconfig', 'lotshape', 'mszoning', 'roofmatl', 'roofstyle',
    'saletype', 'street', 'utilities'
]]

# %%
fig = plt.figure(figsize = (30, 200))

for i, j in enumerate(X_train_obj.columns):
    plt.ylim(0, 650000)
    fig.add_subplot(22, 2, i+1)
    sns.boxplot(x = train[j], y = train['saleprice'], )
# Out:
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
X_train_obj = pd.get_dummies(X_train_obj)

# %%
X_train_obj.fillna(value = 0, inplace = True)
X_train_obj.isnull().sum()
# Out:
# bsmtcond_Ex          0
# bsmtcond_Fa          0
# bsmtcond_Gd          0
# bsmtcond_Po          0
# bsmtcond_TA          0
# centralair_N         0
# centralair_Y         0
# condition1_Artery    0
# condition1_Feedr     0
# condition1_Norm      0
# condition1_PosA      0
# condition1_PosN      0
# condition1_RRAe      0
# condition1_RRAn      0
# condition1_RRNe      0
# condition1_RRNn      0
# condition2_Artery    0
# condition2_Feedr     0
# condition2_Norm      0
# condition2_PosA      0
# condition2_PosN      0
# condition2_RRAe      0
# condition2_RRAn      0
# condition2_RRNn      0
# electrical_FuseA     0
# electrical_FuseF     0
# electrical_FuseP     0
# electrical_Mix       0
# electrical_SBrkr     0
# exterqual_Ex         0
#                     ..
# mszoning_I (all)     0
# mszoning_RH          0
# mszoning_RL          0
# mszoning_RM          0
# roofmatl_ClyTile     0
# roofmatl_CompShg     0
# roofmatl_Membran     0
# roofmatl_Tar&Grv     0
# roofmatl_WdShake     0
# ...

# %%
test = pd.DataFrame(pd.read_csv('test.csv'))
test.columns = [i.lower().replace(' ', '') for i in test.columns]

# %%
test.loc[:, ['1stflrsf', '2ndflrsf', 'bsmtunfsf', 'bsmtfinsf1', 'garagearea', 'garageyrblt',
             'grlivearea', 'lotfrontage', 'masvnrarea', 'openporchsf', 'overallqual', 'screenporch', 'totalbsmtsf', 'totrmsabvgrd', 'wooddecksf', 'yearbuilt']].dtypes
# Out:
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   from ipykernel import kernelapp as app
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/core/indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# 1stflrsf          int64
# 2ndflrsf          int64
# bsmtunfsf       float64
# bsmtfinsf1      float64
# garagearea      float64
# garageyrblt     float64
# grlivearea      float64
# ...

# %%
X_test_num = test.loc[:, [#'id',
                            '1stflrsf', '2ndflrsf', 'bsmtunfsf', 'bsmtfinsf1', 'garagearea',
                            'garageyrblt', 'grlivearea', 'lotfrontage', 'masvnrarea', 
                            'openporchsf', 'overallqual', 'screenporch', 'totalbsmtsf', 
                            'totrmsabvgrd', 'wooddecksf', 'yearbuilt'
                            #'saleprice'
]]

X_test_num.fillna(value = 0, inplace = True)
X_test_num.isnull().sum()
# Out:
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel/__main__.py:5: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# /Users/chelen/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/core/indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# 1stflrsf        0
# 2ndflrsf        0
# bsmtunfsf       0
# bsmtfinsf1      0
# garagearea      0
# garageyrblt     0
# grlivearea      0
# lotfrontage     0
# masvnrarea      0
# openporchsf     0
# overallqual     0
# ...

# %%
y_test_num = lr.predict(X_test_num)

# %%
X_test_num['id'] = test['id']
X_test_num['saleprice'] = y_test_num.round(2)

# %%
X_test_num.head()
sample5 = X_test_num.loc[:,['id', 'saleprice']]

# %%
sample5.columns = [i.capitalize() for i in sample5.columns]
sample5.set_index('Id', inplace = True)
sample5.sort_index(axis = 0, inplace = True)

# %%
sample5.to_csv('sample5_hc')
pd.read_csv('sample5_hc').head()
# Out:
#    Id  Saleprice
# 0   2  149006.97
# 1   4  242901.54
# 2   6  194151.76
# 3   7  227904.05
# 4  17  245188.97
